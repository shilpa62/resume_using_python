# %% [markdown]
# # Resume using matplotlib library in python

# %%
# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.'
Name = 'SHILPA'
Contact = 'Haryana,India\nPhone No.- 90XXXXXX\nshilpasingla62@gmail.com\nlinkedin.com/in/shilpa62\ngithub.com/shilpa62'

EduHeader = 'EDUCATION'
EduOneTitle = "Kurukshetra University, Master's in Statistics"
EduOneTime = '2017-2019'
EduOneDesc = ' CGPA- 9.19/10'
EduTwoTitle = "Kurukshetra University, Bachelor's in Science"
EduTwoTime = '2014-2017'
EduTwoDesc = '- Majors - Statistics, Mathematics, Computer Science '

WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Chegg Inc. / Subject Matter Expert- Statistics '
WorkOneTime = ' 5 / 2019 - Present'
WorkOneDesc = '- Providing answers to the questions posted  by students '
WorkTwoTitle = 'Indian Council of Medical Research/ Trainee'
WorkTwoTime = '6 / 2018 - 6 / 2018'
WorkTwoDesc = '- Worked on a project named "Implmentation of Janani Sursaksha Yojna" \n using SPSS tools and learned about R software.'
 
CertHeader = "CERTIFICATIONS" 
CertOneTitle = "Master's in Data Science"
CertOneInst = 'Certification by Madrid Software Solutions'
CertTwoTitle ='Python for Data Science, NPTEL - IIT Madras'
CertTwoInst='Scored-92 marks (Gold + Elite Type Certificate)'
CertThreeTitle = 'Introduction to R, NPTEL - IIT Kanpur'
CertThreeInst= 'Scored-91 marks(Gold + Elite Type Certificate)'
CertFourTitle= 'One Week Training Programme on Official Statistics'
CertFourInst ='National Statistical System Training Academy'
CertFiveTitle= 'Introduction to R '
CertFiveInst='Swayam Online Course by IIT Madras'
CertSixTitle='Short Term Training Programme on Medical Statistics'
CertSixInst='ICMR- New Delhi'

SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Machine learning\n- R programmimg\n- NumPy\n- Pandas\n- Data Visualization\n- SPSS\n- Scikit\n- C\n- MYSql\n- Probability/Statistics\n- Data Manipulation\n- Excel'
ExtrasTitle = 'Strengths'
ExtrasDesc = '- Quick Learner\n- Strong will power \n- Disciplined and Punctual'

# %%
# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.8, xmin=0, xmax=10, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.88), weight='bold', fontsize=44)
plt.annotate(Contact, (.7,.859), weight='bold', fontsize=12, color='white')

plt.annotate(WorkHeader, (.02,.77), weight='bold', fontsize=11, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.73), weight='bold', fontsize=11)
plt.annotate(WorkOneTime, (.02,.71), weight='regular', fontsize=10, alpha=.7)
plt.annotate(WorkOneDesc, (.02,.69), weight='regular', fontsize=10)
plt.annotate(WorkTwoTitle, (.02,.66), weight='bold', fontsize=11)
plt.annotate(WorkTwoTime, (.02,.64), weight='regular', fontsize=10, alpha=.7)
plt.annotate(WorkTwoDesc, (.02,.60), weight='regular', fontsize=10)

plt.annotate(EduHeader, (.02,.55), weight='bold', fontsize=11, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.52), weight='bold', fontsize=11)
plt.annotate(EduOneTime, (.02,.50), weight='regular', fontsize=10, alpha=.6)
plt.annotate(EduOneDesc, (.02,.48), weight='regular', fontsize=10)
plt.annotate(EduTwoTitle, (.02,.45), weight='bold', fontsize=11)
plt.annotate(EduTwoTime, (.02,.43), weight='regular', fontsize=10, alpha=.6)
plt.annotate(EduTwoDesc, (.02,.41), weight='regular', fontsize=10)

plt.annotate(CertHeader, (.02,.36), weight='bold', fontsize=11, color='#58C1B2')
plt.annotate(CertOneTitle, (.02,.33), weight='bold', fontsize=11)
plt.annotate(CertOneInst, (.02,.31), weight='regular', fontsize=10)
plt.annotate(CertTwoTitle, (.02,.28), weight='bold', fontsize=11)
plt.annotate(CertTwoInst, (.02,.26), weight='regular', fontsize=10)
plt.annotate(CertThreeTitle, (.02,.23), weight='bold', fontsize=11)
plt.annotate(CertThreeInst, (.02,.21), weight='regular', fontsize=10)
plt.annotate(CertFourTitle, (.02,.18), weight='bold', fontsize=11)
plt.annotate(CertFourInst, (.02,.16), weight='regular', fontsize=10)
plt.annotate(CertFiveTitle, (.02,.13), weight='bold', fontsize=11)
plt.annotate(CertFiveInst, (.02,.11), weight='regular', fontsize=10)
plt.annotate(CertSixTitle, (.02,.08), weight='bold', fontsize=11)
plt.annotate(CertSixInst, (.02,.05), weight='regular', fontsize=10)

plt.annotate(SkillsHeader, (.7,.70), weight='bold', fontsize=14, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.39), weight='regular', fontsize=12, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.29), weight='bold', fontsize=14, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.20), weight='regular', fontsize=12, color='#ffffff')

plt.savefig("shilparesume.png")
